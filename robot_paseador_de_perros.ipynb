# %% [markdown]
# <a href="https://colab.research.google.com/github/barbycardozo81/InicioPython/blob/main/robot_paseador_de_perros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Función de inicio
def inicio():
    print("🐶 Iniciando sistema de paseo de perros...\n")


# Función para identificar al perro
def identificar_perro():
    nombre = input("Ingrese el nombre del perro: ")
    raza = input("Ingrese la raza del perro: ")

    print("\nPerro identificado:")
    print("Nombre:", nombre)
    print("Raza:", raza)

    return nombre


# Función para preparar al perro
def preparar_perro(nombre):
    print(f"Preparando a {nombre} para el paseo...")
    print("✔ Collar colocado")
    print("✔ Correa asegurada")
    print("✔ Bolsas listas\n")

# Función para verificar el clima
def verificar_clima():
    clima = input("¿Cómo está el clima hoy? (soleado/lluvioso): ").lower()

    if clima == "lluvioso":
        print("☔ El clima es lluvioso. Llevar impermeable.\n")
    else:
        print("☀ Buen clima para pasear.\n")
