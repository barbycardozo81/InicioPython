# %% [markdown]
# <a href="https://colab.research.google.com/github/barbycardozo81/InicioPython/blob/main/matrices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Vector de la pelicula "Matrix"
matrix = [1,0,1,0,1] # [Acción, Comedia, Ciencia Ficción, Drama, Suspenso ]
el_padrino = [0,0,0,1,0]
similitud = sum([a*b for a ,b in zip(matrix, el_padrino)])
print(f"La similitud entre Matrix y El Padrino es: {similitud}")
# Out:
# La similitud entre Matrix y El Padrino es: 0
