# %% [markdown]
# <a href="https://colab.research.google.com/github/barbycardozo81/InicioPython/blob/main/matrice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
correo = ["oferta", "gratis", "dinero", "ganar", "clic"]
spam_words = ["oferta", "gratis", "dinero", "ganar", "clic"]
cantidad_spam = sum([1 for word in correo if word in spam_words])
if cantidad_spam > 2:
  print("¡Alerta! Este correo electrónico podría ser spam. ")
else:
  print("Este correo parece ser legítimo. ")
# Out:
# ¡Alerta! Este correo electrónico podría ser spam.
